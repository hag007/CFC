# %% [markdown]
# # שבוע 11 — ניתוח נתונים עם Pandas
#
# בשבוע האחד־עשר נלמד לעבוד עם **Pandas**, הספרייה המרכזית לעיבוד וניתוח נתונים בפייתון.
# זוהי אחת מהמיומנויות החשובות ביותר לכל מי שעוסק במדע נתונים, ניסויים, או ניתוח תוצאות מדידה.
# נלמד כיצד לטעון נתונים מקבצים שונים, לנקותם, למיין ולסנן אותם, ולבצע עליהם פעולות מתקדמות
# כמו קיבוץ, המרה ושרטוט מהיר של תוצאות.
#
# נבין כיצד להשתמש במבני הנתונים החזקים של הספרייה — `Series` ו־`DataFrame`,
# ונראה כיצד הם מאפשרים עבודה מהירה ואינטואיטיבית עם כמויות גדולות של מידע מדעי או ניסויי.
#
# בסוף השבוע תדעו:
# - ליצור ולעבוד עם מבני הנתונים `Series` ו־`DataFrame`
# - לייבא ולייצא נתונים מקבצים
# - לבחור, למיין ולסנן נתונים לפי תנאים שונים
# - לנקות נתונים ולזהות סוגי משתנים בצורה יעילה
# - לבצע טרנספורמציות ווקטוריות ולחשב עמודות חדשות
# - לקבץ נתונים (`groupby`) ולחשב סטטיסטיקות
# - לעצב מחדש טבלאות (`pivot`, `melt`) ולמזג כמה מקורות מידע
# - לעבוד עם נתוני זמן (`DatetimeIndex`, `resample`)
# - להפיק תובנות מהירות בעזרת שרטוטים בסיסיים מתוך Pandas
#
# ## Materials
# - {doc}`0 • מבוא לעבודה עם Pandas <../../course/weeks/week_11/11_0_intro>`
# - {doc}`1 • מבני נתונים: Series ו־DataFrame <../../course/weeks/week_11/11_1_data_structures>`
# - {doc}`2 • טעינה וכתיבה של נתונים (I/O) <../../course/weeks/week_11/11_2_io>`
# - {doc}`3 • מיון, סינון ואינדוקס נתונים <../../course/weeks/week_11/11_3_indexing_select_filter>`
# - {doc}`4 • ניקוי נתונים וטיפול בסוגי עמודות <../../course/weeks/week_11/11_4_cleaning_type_handling>`
# - {doc}`5 • טרנספורמציות וקטוריות <../../course/weeks/week_11/11_5_vector_transform>`
# - {doc}`6 • קיבוץ וצבירה (Grouping & Aggregation) <../../course/weeks/week_11/11_6_grouping_aggregation>`
# - {doc}`7 • עיצוב מחדש של טבלאות (Reshaping) <../../course/weeks/week_11/11_7_reshaping_dataframes>`
# - {doc}`8 • מיזוג וחיבור בין טבלאות (Merging & Joining) <../../course/weeks/week_11/11_8_merging_joining>`
# - {doc}`9 • עבודה עם סדרות זמן (Time Series) <../../course/weeks/week_11/11_9_time_series>`
# - {doc}`10 • חקירת נתונים ושרטוטים מהירים <../../course/weeks/week_11/11_10_exploration_quick_plots>`
