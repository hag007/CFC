# %% [markdown]
# # שבוע 1 — טיפוסים
#
# ברוכים הבאים לשבוע הראשון בקורס!
# בשבוע זה נלמד את יסודות השפה — מהבנה בסיסית של מחשבים ותוכנה, דרך היכרות עם שפת פייתון, ועד לעבודה עם משתנים, טיפוסים שונים.
# נפתח בהיכרות עם הרעיון של חומרה ותוכנה, ולאחר מכן נצלול לשפת פייתון עצמה:
# נלמד מהו משתנה וכיצד נותנים לו שם, נכיר את הטיפוסים הבסיסיים (מספרים, בוליאנים, מחרוזות), ונראה כיצד ממירים ביניהם כדי לבצע חישובים ולבנות ביטויים לוגיים.
#
# בסוף השבוע תדעו:
# - מהו טיפוס נתונים וכיצד הוא משפיע על פעולות החישוב
# - כיצד להגדיר ולהשתמש במשתנים
# - איך לכתוב קוד קריא וברור שמגיב למצבים שונים
#
# ## Materials
# - {doc}`1 • מבוא <../../vendor/virtual-pyprog/0_0_objectives>`
# - {doc}`2 • חומרה, תוכנה והשיטה הבינארית <../../vendor/virtual-pyprog/0_1_hardware-to-software>`
# - {doc}`3 • שפת התכנות פייתון <../../vendor/virtual-pyprog/0_2_python>`
# - {doc}`4 • משתנים והשמות <../../vendor/virtual-pyprog/0_3_variables-and-assignments>`
# - {doc}`5 • מבוא לטיפוסים <../../vendor/virtual-pyprog/1_0_intro_types>`
# - {doc}`6 • טיפוסים נומריים <../../vendor/virtual-pyprog/1_1_numerical_types>`
# - {doc}`7 • משתנים בוליאניים <../../vendor/virtual-pyprog/1_2_booleans>`
# - {doc}`8 • מחרוזות <../../vendor/virtual-pyprog/1_3_strings>`
# - {doc}`9 • המרות בין טיפוסים <../../vendor/virtual-pyprog/1_4_conversion>`
