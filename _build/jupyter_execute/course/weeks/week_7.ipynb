# %% [markdown]
# # שבוע 7 — תכנות מונחה־עצמים (OOP)
#
# בשבוע השנים־עשר נלמד על **תכנות מונחה־עצמים (Object-Oriented Programming)**
#
# בחלק הראשון של השבוע נלמד את עקרונות ה־OOP — אחת מתפיסות היסוד בתכנות מודרני.
# נראה כיצד ניתן לארגן קוד סביב **אובייקטים**, ו**מחלקות**
#
# בסוף השבוע תדעו להגדיר וליישם מחלקות (Classes) ואובייקטים (Objects) בפייתון.
#
# ## Materials
# - {doc}`0 • מבוא לתכנות מונחה־עצמים (OOP) <../../vendor/virtual-pyprog/17_0_oop-intro>`
# - {doc}`1 • מימוש עקרונות OOP בפייתון <../../vendor/virtual-pyprog/17_1_oop-implementation>`
