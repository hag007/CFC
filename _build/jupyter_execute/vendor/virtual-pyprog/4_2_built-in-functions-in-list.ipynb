# %%
# %%html
# <script>
# (function() {
#   // Create the toggle button
#   const rtlButton = document.createElement("button");
#   rtlButton.textContent = "Toggle LTR";
#   rtlButton.id = "top-rtl-toggle";
#   rtlButton.style.marginLeft = "8px";
#   rtlButton.style.padding = "4px 10px";
#   rtlButton.style.fontSize = "14px";
#   rtlButton.style.cursor = "pointer";
#
#   // State
#   var rtlActive = false;
#
#   // Styling function
#   var applyStyleToEditor = (editor) => {
#     if (!editor) return;
#     var direction = getComputedStyle(editor).getPropertyValue('direction')=='rtl' ? 'ltr' : 'rtl';
#     var text_align = getComputedStyle(editor).getPropertyValue('text-align')=='right' ? 'left' : 'right';
#     editor.style.setProperty('direction', direction, 'important');
#     editor.style.setProperty('text-align', text_align, 'important');
#   };
#
#   // Toggle logic
#   rtlButton.onclick = () => {
#     rtlActive = !rtlActive;
#     rtlButton.textContent = rtlActive ? "Toggle LTR" : "Toggle RTL";
#     document.querySelectorAll('.jp-MarkdownCell .jp-InputArea-editor').forEach(applyStyleToEditor);
#     document.querySelectorAll('.jp-RenderedHTMLCommon code, .jp-RenderedHTMLCommon code span').forEach(applyStyleToEditor);
#     document.querySelectorAll('jp-RenderedHTMLCommon, .jp-RenderedHTMLCommon *').forEach(applyStyleToEditor);
#   };
#
#   // Watch for focus into editing Markdown cells
#   // document.addEventListener('focusin', (event) => {
#   //   const editor = event.target.closest('.jp-MarkdownCell .jp-InputArea-editor');
#   //    if (editor) applyStyleToEditor(editor);
#   // });
#
#   // Insert into top toolbar if not already present
#   var insertIntoToolbar = () => {
#     const toolbar = document.querySelector('.jp-NotebookPanel-toolbar');
#     if (toolbar && !document.getElementById("top-rtl-toggle")) {
#       toolbar.appendChild(rtlButton);
#     } else {
#       // Try again in a moment if toolbar isn't ready yet
#       setTimeout(insertIntoToolbar, 300);
#     }
#   };
#
#   insertIntoToolbar();
# })();
# </script>
# Out:
# <script>
# (function() {
#   // Create the toggle button
#   const rtlButton = document.createElement("button");
#   rtlButton.textContent = "Toggle LTR";
#   rtlButton.id = "top-rtl-toggle";
#   rtlButton.style.marginLeft = "8px";
#   rtlButton.style.padding = "4px 10px";
#   rtlButton.style.fontSize = "14px";
#   rtlButton.style.cursor = "pointer";
#
#   // State
#   var rtlActive = false;
#
#   // Styling function
#   var applyStyleToEditor = (editor) => {
#     if (!editor) return;
#     var direction = getComputedStyle(editor).getPropertyValue('direction')=='rtl' ? 'ltr' : 'rtl';
#     var text_align = getComputedStyle(editor).getPropertyValue('text-align')=='right' ? 'left' : 'right';
#     editor.style.setProperty('direction', direction, 'important');
#     editor.style.setProperty('text-align', text_align, 'important');
#   };
#
#   // Toggle logic
#   rtlButton.onclick = () => {
#     rtlActive = !rtlActive;
# ...

# %% [markdown]
# ## פונקציות מובנות של רשימות

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/SVDkhNexrAA?si=TxvuWk2ehZ9eR1tR" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/SVDkhNexrAA?si=TxvuWk2ehZ9eR1tR" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# בסרטון זה למדנו מספר פונקציות חדשות שמיועדות לעבודה עם רשימות. בנוסף, ראינו הבדל חשוב בין מחרוזות לרשימות: בעוד שמחרוזות אינן ניתנות לשינוי, ברשימות אפשר לשנות את הערך של כל איבר באופן ישיר.
#
# בין הפונקציות השימושיות שלמדנו עד כה:
# - `len` – מחזירה את האורך של הרשימה
# - `sum` – מחזירה את הסכום של כל איברי הרשימה
# - `min` – מחזירה את האיבר הקטן ביותר
# - `max` – מחזירה את האיבר הגדול ביותר
# - `sorted` – מחזירה רשימה חדשה ממויינת
# - `in` – מחזירה `True` אם איבר נמצא ברשימה
#
# תיעוד מלא על רשימות בפייתון זמין [כאן](https://docs.python.org/3/tutorial/datastructures.html)

# %% [markdown]
# <h4 style="color:purple">
# בחנו את עצמכם
# </h4>

# %% [markdown]
# השאלות הבאות מתייחסות לשלוש הרשימות הבאות:
# ```python
# L1 = [5, 1, 4, 3, 2]
# L2 = [7, 6, 8]
# L3 = []
# ```
# בכל שאלה תופיע פקודה מסוימת המערבת את אחת או יותר מהרשימות הנ"ל. עליכם לסמן מהו הערך המוחזר מהפקודה, או לסמן כי הפקודה מביאה לשגיאה.
#
# לשם הנוחות, יצרנו חלונית קוד בה תוכלו לבדוק את עצמכם ולהשתכנע בנכונות התשובות. אנו ממליצים לענות תחילה על כל השאלות ולאחר מכן לבדוק את עצמכם בחלונית הקוד.

# %%
L1 = [1,2,3,4,5]
L2 = [6,7,8]
L3 = []

# check your answers here:

# %%
import json
from jupyterquiz import display_quiz

example = \
'''
[{
    "question": "מה תהיה התוצאה של max(L1)?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "הפקודה גורמת לשגיאה",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "1",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "5",
            "correct": true,
            "feedback": "נכון!"
        },
        {
            "answer": "4",
            "correct": false,
            "feedback": "לא נכון"
        }
    ]
}]
'''
myquiz = json.loads(example)
display_quiz(myquiz)
# Out:
# <div id="okVdKSLpcsAC" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #okVdKSLpcsAC {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %%
import json
from jupyterquiz import display_quiz

example = \
'''
[{
    "question": "מה תהיה התוצאה של min(L2)?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "הפקודה גורמת לשגיאה",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "8",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "6",
            "correct": true,
            "feedback": "נכון!"
        },
        {
            "answer": "7",
            "correct": false,
            "feedback": "לא נכון"
        }
    ]
}]
'''
myquiz = json.loads(example)
display_quiz(myquiz)
# Out:
# <div id="flKAEvXLEAQQ" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #flKAEvXLEAQQ {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %%
import json
from jupyterquiz import display_quiz

example = \
'''
[{
    "question": "מה תהיה התוצאה של min(L1) + max(L2)?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "הפקודה גורמת לשגיאה",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "10",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "9",
            "correct": true,
            "feedback": "נכון!"
        },
        {
            "answer": "11",
            "correct": false,
            "feedback": "לא נכון"
        }
    ]
}]
'''
myquiz = json.loads(example)
display_quiz(myquiz)
# Out:
# <div id="hVjmPxuDrimy" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #hVjmPxuDrimy {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %%
import json
from jupyterquiz import display_quiz

example = \
'''
[{
    "question": "מה תהיה התוצאה של min(L3) + max(L2)?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "הפקודה גורמת לשגיאה",
            "correct": true,
            "feedback": "נכון!"
        },
        {
            "answer": "7",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "8",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "6",
            "correct": false,
            "feedback": "לא נכון"
        }
    ]
}]
'''
myquiz = json.loads(example)
display_quiz(myquiz)
# Out:
# <div id="btxHAVnjQnVx" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #btxHAVnjQnVx {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %%
import json
from jupyterquiz import display_quiz

example = \
'''
[{
    "question": "מה תהיה התוצאה של sorted(L2 + L1) == sorted(L2) + sorted(L1)?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "הפקודה גורמת לשגיאה",
            "correct": false,
            "feedback": "לא נכון"
        },
        {
            "answer": "False",
            "correct": true,
            "feedback": "נכון!"
        },
        {
            "answer": "True",
            "correct": false,
            "feedback": "לא נכון"
        }
    ]
}]
'''
myquiz = json.loads(example)
display_quiz(myquiz)
# Out:
# <div id="vFhGvzXacfqw" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #vFhGvzXacfqw {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %%
import json
from jupyterquiz import display_quiz

example = \
'''
[{
    "question": "מה תהיה התוצאה של sorted(L3)?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "הפקודה גורמת לשגיאה",
            "correct": false,
            "feedback": "לא נכון"

        },
        {
            "answer": "[]",
            "correct": true,
            "feedback": "נכון!"

        },
        {
            "answer": "None",
            "correct": false,
            "feedback": "לא נכון"
        }
    ]
}]
'''
myquiz = json.loads(example)
display_quiz(myquiz)
# Out:
# <div id="DTdQNxqvhbQt" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #DTdQNxqvhbQt {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...
